# %%
# auto reload modules
# %load_ext autoreload
# %autoreload 2

# %%
#%%
from cns.pipelines import main_aggregate, main_segment
from cns.process.segments import regions_select
from cns.data_utils import load_samples_out, load_cns_out
import time
# Out:
# c:\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from cns.utils.selection import cns_head


tracerx_cns_df = load_cns_out("TRACERx_cns_fill.tsv")
top_df = cns_head(tracerx_cns_df, 20)
tracerx_samples_df = load_samples_out("TRACERx_samples.tsv")

select_regs = regions_select("whole")
remove_regs = regions_select("gaps")
hg19_segs = main_segment(tracerx_cns_df, select_regs, remove_regs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24152/2110516444.py in <module>
#       2
#       3
# ----> 4 tracerx_cns_df = load_cns_out("TRACERx_cns_fill.tsv", raw=True)
#       5 top_df = cns_head(tracerx_cns_df, 20)
#       6 tracerx_samples_df = load_samples_out("TRACERx_samples.tsv")
#
# TypeError: load_cns_out() got an unexpected keyword argument 'raw'

# %%
start_time = time.time()

main_aggregate(top_df, hg19_segs, "none", print_info=True)

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Time taken: {elapsed_time:.4f} seconds")
# Out:
# Aggregated into 15046 CNS.
# Time taken: 0.1962 seconds
