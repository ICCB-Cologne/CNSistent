# %%
# set auto-reload of the notebook
# %load_ext autoreload
# %autoreload 2

# %%
import cns
import cns.data_utils as cdu
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 10)
# set color_map to tab10
color_map = plt.cm.get_cmap('tab10').colors[:10]
plt.rcParams.update({'font.size': 12})
# Out:
# C:\Users\adams\AppData\Local\Temp\ipykernel_83828\27608293.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('tab10').colors[:10]

# %%
gene_scores = pd.read_csv("../out/gene_scores_all.tsv", sep="\t")
ordered_df = gene_scores.sort_values(by=["score"], ascending=False)

# %%
ordered_df["score"].sum()
# Out:
# -152.86349739566367

# %%
tsgs_df = ordered_df.query("score > 0")[["chrom", "start", "end", "name", "score"]].copy()
print(tsgs_df["score"].describe())
tsgs_df.to_csv(cdu.pjoin(cdu.out_path, "tsgs_cnsistent_full.tsv"), sep="\t", index=False, header=False)
# Out:
# (10605, 5)
# count    10605.000000
# mean         0.192502
# std          0.087250
# min          0.000039
# 25%          0.132461
# 50%          0.196870
# 75%          0.242284
# max          0.448046
# Name: score, dtype: float64

# %%
ogs_df = ordered_df.query("score <= 0")[["chrom", "start", "end", "name", "score"]].copy()
print(ogs_df.shape)
ogs_df["score"] = -ogs_df["score"] 
print(ogs_df["score"].describe())
ogs_df.to_csv(cdu.pjoin(cdu.out_path, "ogs_cnsistent_full.tsv"), sep="\t", index=False, header=False)
# Out:
# (8825, 5)
# count    8825.000000
# mean        0.248651
# std         0.219396
# min         0.000060
# 25%         0.060386
# 50%         0.175696
# 75%         0.455097
# max         1.025000
# Name: score, dtype: float64

# %%
ordered_df.query("score < 0").count()
# Out:
# chrom       8825
# start       8825
# end         8825
# name        8825
# score       8825
# total_cn    8825
# gene         323
# dtype: int64

# %%
tsgs_df["score"].mean()
# Out:
# 0.19250182943902674
