# %%
import pandas as pd
import numpy as np
import cns.data_utils as cdu
import cns
import time

# %%
# start timer
start = time.time()

samples_df, cns_df = cdu.main_load("1MB")
subs_df = cns.cns_head(cns_df, 100)

ids = subs_df.index.unique()
arr  = np.zeros((len(ids), len(ids)))
for i1, id1 in enumerate(ids):
    for i2, id2 in enumerate(ids[:i1]):
        cns1 = subs_df.loc[id1]
        cns2 = subs_df.loc[id2]
        dist = cns.calc_wass_distance(cns1, cns2, "total_cn")
        arr[i1, i2] = dist.mean()

print(f"Elapsed time: {time.time() - start:.2f} seconds")

arr = pd.DataFrame(arr, index=ids, columns=ids)
arr.to_csv(cdu.pjoin(cdu.out_path, "LUAD_LUSC_wass_dist.tsv", sep="\t", index=True, header=True))
# Out:
# Elapsed time: 33.55 seconds
# sample_id          CRUK0001_SU_T1-R1  CRUK0001_SU_T1-R2  CRUK0001_SU_T1-R3  \
# sample_id
# CRUK0001_SU_T1-R1           0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R2           0.024883           0.000000           0.000000
# CRUK0001_SU_T1-R3           0.034244           0.032240           0.000000
# CRUK0002_SU_T1-R1           0.047661           0.043373           0.047821
# CRUK0002_SU_T1-R2           0.045088           0.039378           0.041798
# ...                              ...                ...                ...
# CRUK0032_SU_T1-R1           0.041028           0.040121           0.039348
# CRUK0032_SU_T1-R2           0.046485           0.046866           0.044010
# CRUK0032_SU_T1-R3           0.041966           0.039813           0.044749
# CRUK0032_SU_T1-R4           0.045852           0.045227           0.045213
# CRUK0033_SU_T1-R1           0.033329           0.029888           0.036483
#
# sample_id          CRUK0002_SU_T1-R1  CRUK0002_SU_T1-R2  CRUK0002_SU_T1-R3  \
# sample_id
# CRUK0001_SU_T1-R1           0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R2           0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R3           0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R1           0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R2           0.015851           0.000000           0.000000
# ...                              ...                ...                ...
# CRUK0032_SU_T1-R1           0.045047           0.041926           0.042633
# CRUK0032_SU_T1-R2           0.047523           0.044451           0.047604
# CRUK0032_SU_T1-R3           0.045659           0.044107           0.045043
# CRUK0032_SU_T1-R4           0.048332           0.045598           0.044748
# CRUK0033_SU_T1-R1           0.028179           0.026181           0.030291
#
# sample_id          CRUK0003_SU_FLN1  CRUK0003_SU_T1-R1  CRUK0003_SU_T1-R2  \
# sample_id
# CRUK0001_SU_T1-R1          0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R2          0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R3          0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R1          0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R2          0.000000           0.000000           0.000000
# ...                             ...                ...                ...
# CRUK0032_SU_T1-R1          0.021868           0.024966           0.024851
# CRUK0032_SU_T1-R2          0.027042           0.024757           0.025075
# CRUK0032_SU_T1-R3          0.024968           0.028015           0.029323
# CRUK0032_SU_T1-R4          0.028643           0.026656           0.026512
# CRUK0033_SU_T1-R1          0.019921           0.012516           0.011334
#
# sample_id          CRUK0003_SU_T1-R3  ...  CRUK0029_SU_T1-R7  \
# sample_id                             ...
# CRUK0001_SU_T1-R1           0.000000  ...           0.000000
# CRUK0001_SU_T1-R2           0.000000  ...           0.000000
# CRUK0001_SU_T1-R3           0.000000  ...           0.000000
# CRUK0002_SU_T1-R1           0.000000  ...           0.000000
# CRUK0002_SU_T1-R2           0.000000  ...           0.000000
# ...                              ...  ...                ...
# CRUK0032_SU_T1-R1           0.020925  ...           0.031535
# CRUK0032_SU_T1-R2           0.022867  ...           0.035836
# CRUK0032_SU_T1-R3           0.025387  ...           0.034997
# CRUK0032_SU_T1-R4           0.023976  ...           0.037586
# CRUK0033_SU_T1-R1           0.009825  ...           0.032257
#
# sample_id          CRUK0029_SU_T1-R8  CRUK0030_SU_T2-R1  CRUK0030_SU_T2-R2  \
# sample_id
# CRUK0001_SU_T1-R1           0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R2           0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R3           0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R1           0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R2           0.000000           0.000000           0.000000
# ...                              ...                ...                ...
# CRUK0032_SU_T1-R1           0.037418           0.032265           0.039942
# CRUK0032_SU_T1-R2           0.042068           0.034525           0.043595
# CRUK0032_SU_T1-R3           0.040486           0.035417           0.042289
# CRUK0032_SU_T1-R4           0.043841           0.036763           0.045611
# CRUK0033_SU_T1-R1           0.036623           0.024259           0.036037
#
# sample_id          CRUK0030_SU_T2-R3  CRUK0032_SU_T1-R1  CRUK0032_SU_T1-R2  \
# sample_id
# CRUK0001_SU_T1-R1           0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R2           0.000000           0.000000           0.000000
# CRUK0001_SU_T1-R3           0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R1           0.000000           0.000000           0.000000
# CRUK0002_SU_T1-R2           0.000000           0.000000           0.000000
# ...                              ...                ...                ...
# CRUK0032_SU_T1-R1           0.040487           0.000000           0.000000
# CRUK0032_SU_T1-R2           0.044454           0.021975           0.000000
# CRUK0032_SU_T1-R3           0.042533           0.009346           0.024808
# CRUK0032_SU_T1-R4           0.046453           0.018356           0.011547
# CRUK0033_SU_T1-R1           0.035288           0.028456           0.030846
#
# sample_id          CRUK0032_SU_T1-R3  CRUK0032_SU_T1-R4  CRUK0033_SU_T1-R1
# sample_id
# CRUK0001_SU_T1-R1           0.000000           0.000000                0.0
# CRUK0001_SU_T1-R2           0.000000           0.000000                0.0
# CRUK0001_SU_T1-R3           0.000000           0.000000                0.0
# CRUK0002_SU_T1-R1           0.000000           0.000000                0.0
# CRUK0002_SU_T1-R2           0.000000           0.000000                0.0
# ...                              ...                ...                ...
# CRUK0032_SU_T1-R1           0.000000           0.000000                0.0
# CRUK0032_SU_T1-R2           0.000000           0.000000                0.0
# CRUK0032_SU_T1-R3           0.000000           0.000000                0.0
# CRUK0032_SU_T1-R4           0.019999           0.000000                0.0
# CRUK0033_SU_T1-R1           0.031546           0.031989                0.0
#
# [100 rows x 100 columns]
