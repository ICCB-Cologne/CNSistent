# %%
# auto reload modules
# %load_ext autoreload
# %autoreload 2

# %%
from cns.data_utils import *

# %%
samples, cns_df = main_load_data("COSMIC")

# %%
samples["source"].value_counts()
# Out:
# source
# TCGA_hg19    8874
# PCAWG        1626
# TRACERx      1172
# Name: count, dtype: int64

# %%
cns_df.query("total_cn < 10")["total_cn"].hist(bins=100)
# Out:
# <Axes: >
