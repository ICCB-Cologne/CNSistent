# %%
import matplotlib.pyplot as plt
import pandas as pd

from cns.display.label import *
from cns.data_utils import load_cns_out
from cns.utils.assemblies import hg19

# auto reload modules
# %load_ext autoreload
# %autoreload 2
# Out:
# c:\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 1), dpi=150)
plot_chr_bg(ax)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 1), dpi=150)
plot_chr_bg(ax, colored=True)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 2), dpi=150)
plot_cytobands(ax, alpha=.5)
add_cytoband_legend(ax)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 2), dpi=150)
plot_cytobands(ax, alpha=1, chrom="chr1")
add_cytoband_legend(ax)

# %%
hg19.cytobands[:5]
# Out:
# (('chr1', 0, 2300000, 'p36.33', 'gneg'),
#  ('chr1', 2300000, 5400000, 'p36.32', 'gpos25'),
#  ('chr1', 5400000, 7200000, 'p36.31', 'gneg'),
#  ('chr1', 7200000, 9200000, 'p36.23', 'gpos25'),
#  ('chr1', 9200000, 12700000, 'p36.22', 'gneg'))

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 2), dpi=150)
plot_gaps(ax, alpha=.5)
add_gap_legend(ax)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 2), dpi=150)
plot_gaps(ax, alpha=1, chrom="chrY")
add_gap_legend(ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16772/246653657.py in <module>
#       1 fig, ax = plt.subplots(1, 1, figsize=(10, 2), dpi=150)
# ----> 2 plot_gaps(ax, alpha=1, sel_chrom="chrY")
#       3 add_gap_legend(ax)
#
# TypeError: plot_gaps() got an unexpected keyword argument 'sel_chrom'

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 2), dpi=150)
plot_x_ticks(ax)
plot_x_lines(ax)
no_y_ticks(ax)
