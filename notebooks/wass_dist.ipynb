# %%
# set auto-reload of the notebook
# %load_ext autoreload
# %autoreload 2

import cns
import cns.data_utils as cdu
import pandas as pd
import matplotlib.pyplot as plt
import time
import numpy as np

pd.set_option('display.max_columns', 10)
# set color_map to tab10
color_map = plt.cm.get_cmap('tab10').colors[:10]
plt.rcParams.update({'font.size': 12})
# Out:
# C:\Users\adams\AppData\Local\Temp\ipykernel_40452\45281415.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('tab10').colors[:10]

# %%
samples_df, cns_df = cdu.main_load("10MB")
subs_df = cns.only_aut(cns.add_total_cn(cns_df))
subs_df = cns.cns_head(subs_df, 100)

# %%
start = time.time()
arr = cns.calc_distances(subs_df)
print(f"Elapsed time: {time.time() - start:.2f} seconds")
arr.to_csv(cdu.pjoin(cdu.out_path, "LUAD_LUSC_wass_dist.tsv"), sep="\t", index=True, header=True)
# Out:
# Elapsed time: 7.81 seconds
